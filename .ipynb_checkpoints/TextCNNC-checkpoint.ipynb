# %%
import tensorflow as tf
import numpy as np
import os
from tensorflow.contrib import learn
from data_helpers import load_data_and_labels, clean_str, get_dir
import data_helpers

from TextCNNClassifier import NN_config, CALC_config, TextCNNClassifier
# Data Preparation
# ==================================================
positive_data_file = "./data/rt-polaritydata/rt-polarity.pos"
negative_data_file = "./data/rt-polaritydata/rt-polarity.neg"
dev_sample_percentage = 0.1
# Load data
print("Loading data...")
x_text, y = data_helpers.load_data_and_labels(positive_data_file, negative_data_file)

# Build vocabulary
max_document_length = max([len(x.split(" ")) for x in x_text])
vocab_processor = learn.preprocessing.VocabularyProcessor(max_document_length)
x = np.array(list(vocab_processor.fit_transform(x_text)))

print('vocabulary length is:',len(vocab_processor.vocabulary_))
# Randomly shuffle data
np.random.seed(10)
shuffle_indices = np.random.permutation(np.arange(len(y)))
x_shuffled = x[shuffle_indices]
y_shuffled = y[shuffle_indices]

# Split train/test set
# TODO: This is very crude, should use cross-validation
dev_sample_index = -1 * int(dev_sample_percentage * float(len(y)))
x_train, x_dev = x_shuffled[:dev_sample_index], x_shuffled[dev_sample_index:]
y_train, y_dev = y_shuffled[:dev_sample_index], y_shuffled[dev_sample_index:]
print('The leangth of X_train is {}'.format(len(x_train)))
print('The length of x_dev is {}'.format(len(x_dev)))
# Out:
# Loading data...
# vocabulary length is: 18758
# The leangth of X_train is 9596
# The length of x_dev is 1066

# %%
#------------------------------------------------------------------------------
# ----------------  model processing ------------------------------------------
#------------------------------------------------------------------------------
num_seqs = max_document_length
num_classes = 2
num_filters = 128
filter_steps = [5,6,7]
embedding_size = 200
vocab_size = len(vocab_processor.vocabulary_)

learning_rate = 0.001
batch_size    = 128
num_epoches   = 20
l2_ratio      = 0.0

trains = list(zip(x_train, y_train))
devs   = list(zip(x_dev,y_dev))

config_nn = NN_config(num_seqs 		= num_seqs,
					  num_classes 	= num_classes,
					  num_filters 	= num_filters,
					  filter_steps 	= filter_steps,
					  embedding_size= embedding_size,
					  vocab_size   	= vocab_size)
config_calc = CALC_config(learning_rate = learning_rate,
						  batch_size 	= batch_size,
						  num_epoches 	= num_epoches,
						  l2_ratio 		= l2_ratio)

# %%
# coding: utf-8
import tensorflow as tf
import numpy as np
import os

class NN_config(object):
	def __init__(self, vocab_size, num_filters,filter_steps,num_seqs=1000,num_classes=2, embedding_size=200):
		self.vocab_size 	= vocab_size
		self.num_filters 	= num_filters
		self.filter_steps 	= filter_steps
		self.num_seqs 		= num_seqs
		self.num_classes 	= num_classes
		self.embedding_size = embedding_size		
		
class CALC_config(object):
	def __init__(self, learning_rate=0.0075, batch_size=64, num_epoches=20, l2_ratio=0.0):
		self.learning_rate = learning_rate
		self.batch_size    = batch_size
		self.num_epoches   = num_epoches
		self.l2_ratio      = l2_ratio

class TextCNNClassifier(object):
	'''
	A class used to define text classifier use convolution network 
	the form of class like keras or scikit-learn
	'''
	def __init__(self,config_nn, config_calc):
		
		self.num_seqs = config_nn.num_seqs
		self.num_classes = config_nn.num_classes
		self.embedding_size = config_nn.embedding_size
		self.vocab_size  = config_nn.vocab_size
		self.num_filters = config_nn.num_filters
		self.filter_steps = config_nn.filter_steps
		
		self.learning_rate = config_calc.learning_rate
		self.batch_size    = config_calc.batch_size
		self.num_epoches   = config_calc.num_epoches
		self.l2_ratio      = config_calc.l2_ratio
		
		#tf.reset_default_graph()
		self.build_placeholder()
		self.build_embedding_layer()
		self.build_nn()
		self.build_cost()
		self.build_optimizer()
		self.saver = tf.train.Saver()
		
	def build_placeholder(self):
		with tf.name_scope('inputs_to_data'):
			self.inputs       = tf.placeholder( tf.int32,shape=[None, self.num_seqs],name='inputs')
			self.targets      = tf.placeholder(tf.float32,shape=[None, self.num_classes], name='targets')
			self.keep_prob    = tf.placeholder(tf.float32, name='nn_keep_prob')
			print('self.inputs.shape:',self.inputs.shape)
	
	def build_embedding_layer(self):
		with tf.device('/cpu:0'),tf.name_scope('embeddings'):
			embeddings = tf.Variable(tf.truncated_normal(shape=[self.vocab_size,self.embedding_size],stddev=0.1),\
						name = 'embeddings')
			x = tf.nn.embedding_lookup(embeddings, self.inputs)
			x = tf.expand_dims(x, axis=-1)
			self.x = tf.cast(x, tf.float32 )
			print('x shape is:',self.x.get_shape())
			
	def build_nn(self):
		conv_out = []
		for i , filter_step in enumerate(self.filter_steps):
			with tf.name_scope("conv-network-%s"%filter_step):
				filter_shape = [filter_step,self.embedding_size, 1,self.num_filters]
				filters = tf.Variable(tf.truncated_normal(shape=filter_shape, stddev=0.1), \
						  name='filters')
				bias    = tf.Variable(tf.constant(0.0, shape=[self.num_filters]), name='bias')
				# h_conv : shape =batch_szie * (num_seqs-filter_step+1) * 1 * num_filters
				h_conv  = tf.nn.conv2d(self.x, 
				                    filter=filters,
									strides = [1,1,1,1],
									padding='VALID',
									name='hidden_conv')  
				h_relu  = tf.nn.relu(tf.nn.bias_add(h_conv,bias),name='relu')
				ksize = [1,self.num_seqs-filter_step+1,1,1]
				#h_pooling: shape = batch_size * 1 * 1 * num_filters
				h_pooling = tf.nn.max_pool(h_relu, 
										   ksize=ksize,
										   strides=[1,1,1,1],
										   padding='VALID',
										   name='pooling')
				conv_out.append(h_pooling)
				
		self.tot_filters_units = self.num_filters * len(self.filter_steps)
		self.h_pool = tf.concat(conv_out,axis=3)
		self.h_pool_flattern =tf.reshape(self.h_pool, shape=[-1, self.tot_filters_units])
		
		with tf.name_scope('dropout'):
			self.h_pool_drop = tf.nn.dropout(self.h_pool_flattern, self.keep_prob)
			
	def build_cost(self):
		with tf.name_scope('cost'):
			W = tf.get_variable(shape=[self.tot_filters_units, self.num_classes],name='W',\
					initializer = tf.contrib.layers.xavier_initializer())
			bias = tf.Variable(tf.constant(0.1, shape=[self.num_classes],name='bias'))			
			self.scores =  tf.nn.xw_plus_b(self.h_pool_drop, W, bias, name='scores')
			self.predictions = tf.argmax(self.scores,axis=1,name='predictions')
			l2_loss = tf.constant(0.0,name='l2_loss')
			l2_loss += tf.nn.l2_loss(W)
			l2_loss += tf.nn.l2_loss(bias)			
			losses = tf.nn.softmax_cross_entropy_with_logits(logits=self.scores, labels=self.targets)
			self.loss = tf.reduce_mean(losses) + self.l2_ratio*l2_loss
			
		with tf.name_scope('accuracy'):
			pred = tf.equal(self.predictions, tf.argmax(self.targets, axis=1))
			self.accuracy = tf.reduce_mean(tf.cast(pred,tf.float32))
			
	def build_optimizer(self):
		with tf.name_scope('optimizer'):
			optimizer = tf.train.AdamOptimizer(self.learning_rate)
			grad_and_vars = optimizer.compute_gradients(self.loss)
			self.train_op = optimizer.apply_gradients(grad_and_vars)
			
	def random_batches(self,data,shuffle=True):
		data = np.array(data)
		data_size = len(data)
		num_batches_per_epoch = int((data_size-1)/self.batch_size) + 1
		if shuffle :
			shuffle_index = np.random.permutation(np.arange(data_size))
			shuffled_data = data[shuffle_index]
		else:
			shuffled_data = data
		#del data
		for epoch in range(self.num_epoches):
			for batch_num in range(num_batches_per_epoch):
				start = batch_num * self.batch_size
				end   = min(start + self.batch_size,data_size)
				yield shuffled_data[start:end]		
	
	def fit(self,data):
		#self.graph = tf.Graph()
		#with self.graph.as_default():
		self.session = tf.Session()
		with self.session as sess:
			#self.saver = tf.train.Saver(tf.global_variables())
			sess.run(tf.global_variables_initializer())
			batches = self.random_batches(list(data))
			accuracy_list = []
			loss_list = []
			#prediction_list = []
			iterations = 0
			# model saving
			save_path = os.path.abspath(os.path.join(os.path.curdir, 'models'))					
			if not os.path.exists(save_path):
				os.makedirs(save_path)
			
			for batch in batches:
				iterations  += 1
				x_batch, y_batch = zip(*batch)
				x_batch = np.array(x_batch)
				y_batch = np.array(y_batch)
				feed = { self.inputs: x_batch,
						 self.targets: y_batch,
						 self.keep_prob: 0.5}
				batch_pred, batch_accuracy, batch_cost, _ = sess.run([self.predictions, self.accuracy,\
														self.loss, self.train_op], feed_dict=feed)
				accuracy_list.append(batch_accuracy)
				loss_list.append(batch_cost)
				
				if iterations % 10 == 0:
					print('The trainning step is {0}'.format(iterations),\
						 'trainning_loss: {:.3f}'.format(loss_list[-1]), \
						 'trainning_accuracy: {:.3f}'.format(accuracy_list[-1]))
				if iterations % 100 == 0:
					self.saver.save(sess, os.path.join(save_path, 'model'), global_step = iterations)
	
			self.saver.save(sess, os.path.join(save_path, 'model'), global_step = iterations)
	
	def load_model(self,start_path=None):
		if start_path == None:
			start_path = os.path.abspath(os.path.join(os.path.curdir,'models','checkpoint'))
			print('default start_path is',start_path)
			#star = start_path
		self.session = tf.Session()
		if start_path == None:
			self.saver.restore(self.session, tf.train.latest_checkpoint(start_path))
		else:
			self.saver.restore(self.session,start_path)
		print('Restored from {} completed'.format(start_path))
		
	def predict_accuracy(self,data,test=True):
		sess = self.session
		iterations = 0
		accuracy_list = []
		predictions = []
		self.num_epoches = 1
		batches = self.random_batches(data,shuffle=False)
		for batch in batches:
			iterations += 1
			x_inputs, y_inputs = zip(*batch)
			x_inputs = np.array(x_inputs)
			y_inputs = np.array(y_inputs)
			feed = {self.inputs: x_inputs,
					self.targets: y_inputs,
					self.keep_prob: 1.0			
				}
			batch_pred, batch_accuracy, batch_loss = sess.run([self.predictions,\
			self.accuracy, self.loss], feed_dict=feed)
			accuracy_list.append(batch_accuracy)
			predictions.append(batch_pred)
			print('The trainning step is {0}'.format(iterations),\
				 'trainning_accuracy: {:.3f}'.format(accuracy_list[-1]))			
			
		accuracy = np.mean(accuracy_list)
		predictions = [list(pred) for pred in predictions]
		predictions = [p for pred in predictions for p in pred]
		predictions = np.array(predictions)
		if test :
			return predictions, accuracy
		else:
			return accuracy
			
	def predict(self, data):
		sess = self.session
		iterations = 0
		predictions_list = []
		self.num_epoches = 1
		batches = self.random_batches(data)
		for batch in batches:
			x_inputs = batch
			feed = {self.inputs : x_inputs,
					self.keep_prob:1.0}
			batch_pred = sess.run([self.predictions],feed_dict=feed)
			predictions_list.append(batch_pred)
		predictions = [list(pred) for pred in predictions]
		predictions = [p for pred in predictions for p in pred]
		predictions = np.array(predictions).reshape(-1,1)
		return predictions

# %%
text_model = TextCNNClassifier(config_nn,config_calc)
# Out:
# self.inputs.shape: (?, 56)
# x shape is: (?, 56, 200, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e9d9854ed419> in <module>()
# ----> 1 text_model = TextCNNClassifier(config_nn,config_calc)
#
# <ipython-input-8-75897187464d> in __init__(self, config_nn, config_calc)
#      43                 self.build_embedding_layer()
#      44                 self.build_nn()
# ---> 45                 self.build_cost()
#      46                 self.build_optimizer()
#      47                 self.saver = tf.train.Saver()
#
# <ipython-input-8-75897187464d> in build_cost(self)
#      94         def build_cost(self):
#      95                 with tf.name_scope('cost'):
# ---> 96                         W = tf.get_variable(shape=[self.tot_filters_units, self.num_classes],name='W',                                  initializer = tf.contrib.layers.xavier_initializer())
#      97                         bias = tf.Variable(tf.constant(0.1, shape=[self.num_classes],name='bias'))
#      98                         self.scores =  tf.nn.xw_plus_b(self.h_pool_drop, W, bias, name='scores')
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter)
#    1063       collections=collections, caching_device=caching_device,
#    1064       partitioner=partitioner, validate_shape=validate_shape,
# -> 1065       use_resource=use_resource, custom_getter=custom_getter)
#    1066 get_variable_or_local_docstring = (
#    1067     """%s
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter)
#     960           collections=collections, caching_device=caching_device,
#     961           partitioner=partitioner, validate_shape=validate_shape,
# --> 962           use_resource=use_resource, custom_getter=custom_getter)
#     963
#     964   def _get_partitioned_variable(self,
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter)
#     365           reuse=reuse, trainable=trainable, collections=collections,
#     366           caching_device=caching_device, partitioner=partitioner,
# --> 367           validate_shape=validate_shape, use_resource=use_resource)
#     368
#     369   def _get_partitioned_variable(
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource)
#     350           trainable=trainable, collections=collections,
#     351           caching_device=caching_device, validate_shape=validate_shape,
# --> 352           use_resource=use_resource)
#     353
#     354     if custom_getter is not None:
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource)
#     662                          " Did you mean to set reuse=True in VarScope? "
#     663                          "Originally defined at:\n\n%s" % (
# --> 664                              name, "".join(traceback.format_list(tb))))
#     665       found_var = self._vars[name]
#     666       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable W already exists, disallowed. Did you mean to set reuse=True in VarScope? Originally defined at:
#
#   File "D:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#   File "D:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "D:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 767, in apply_op
#     op_def=op_def)

# %%
text_model.fit(trains)
# Out:
# The trainning step is 10 trainning_loss: 0.893 trainning_accuracy: 0.438
# The trainning step is 20 trainning_loss: 0.776 trainning_accuracy: 0.539
# The trainning step is 30 trainning_loss: 0.840 trainning_accuracy: 0.500
# The trainning step is 40 trainning_loss: 0.786 trainning_accuracy: 0.469
# The trainning step is 50 trainning_loss: 0.755 trainning_accuracy: 0.500
# The trainning step is 60 trainning_loss: 0.749 trainning_accuracy: 0.516
# The trainning step is 70 trainning_loss: 0.817 trainning_accuracy: 0.461
# The trainning step is 80 trainning_loss: 0.493 trainning_accuracy: 0.758
# The trainning step is 90 trainning_loss: 0.598 trainning_accuracy: 0.664
# The trainning step is 100 trainning_loss: 0.520 trainning_accuracy: 0.750
# The trainning step is 110 trainning_loss: 0.514 trainning_accuracy: 0.727
# The trainning step is 120 trainning_loss: 0.535 trainning_accuracy: 0.734
# The trainning step is 130 trainning_loss: 0.504 trainning_accuracy: 0.758
# The trainning step is 140 trainning_loss: 0.419 trainning_accuracy: 0.844
# The trainning step is 150 trainning_loss: 0.425 trainning_accuracy: 0.806
# The trainning step is 160 trainning_loss: 0.365 trainning_accuracy: 0.836
# The trainning step is 170 trainning_loss: 0.375 trainning_accuracy: 0.859
# The trainning step is 180 trainning_loss: 0.373 trainning_accuracy: 0.797
# The trainning step is 190 trainning_loss: 0.357 trainning_accuracy: 0.859
# The trainning step is 200 trainning_loss: 0.280 trainning_accuracy: 0.883
# The trainning step is 210 trainning_loss: 0.301 trainning_accuracy: 0.859
# The trainning step is 220 trainning_loss: 0.285 trainning_accuracy: 0.891
# The trainning step is 230 trainning_loss: 0.216 trainning_accuracy: 0.945
# The trainning step is 240 trainning_loss: 0.236 trainning_accuracy: 0.938
# The trainning step is 250 trainning_loss: 0.171 trainning_accuracy: 0.945
# The trainning step is 260 trainning_loss: 0.199 trainning_accuracy: 0.938
# The trainning step is 270 trainning_loss: 0.146 trainning_accuracy: 0.977
# The trainning step is 280 trainning_loss: 0.137 trainning_accuracy: 0.969
# The trainning step is 290 trainning_loss: 0.129 trainning_accuracy: 0.969
# The trainning step is 300 trainning_loss: 0.136 trainning_accuracy: 0.944
# The trainning step is 310 trainning_loss: 0.138 trainning_accuracy: 0.969
# The trainning step is 320 trainning_loss: 0.141 trainning_accuracy: 0.961
# The trainning step is 330 trainning_loss: 0.096 trainning_accuracy: 0.984
# The trainning step is 340 trainning_loss: 0.126 trainning_accuracy: 0.945
# The trainning step is 350 trainning_loss: 0.058 trainning_accuracy: 0.992
# The trainning step is 360 trainning_loss: 0.080 trainning_accuracy: 0.977
# The trainning step is 370 trainning_loss: 0.077 trainning_accuracy: 0.992
# The trainning step is 380 trainning_loss: 0.046 trainning_accuracy: 0.992
# The trainning step is 390 trainning_loss: 0.083 trainning_accuracy: 0.969
# The trainning step is 400 trainning_loss: 0.081 trainning_accuracy: 0.977
# The trainning step is 410 trainning_loss: 0.077 trainning_accuracy: 0.961
# The trainning step is 420 trainning_loss: 0.048 trainning_accuracy: 0.992
# The trainning step is 430 trainning_loss: 0.050 trainning_accuracy: 0.984
# The trainning step is 440 trainning_loss: 0.038 trainning_accuracy: 0.992
# The trainning step is 450 trainning_loss: 0.035 trainning_accuracy: 1.000
# The trainning step is 460 trainning_loss: 0.036 trainning_accuracy: 1.000
# The trainning step is 470 trainning_loss: 0.045 trainning_accuracy: 0.992
# The trainning step is 480 trainning_loss: 0.030 trainning_accuracy: 1.000
# The trainning step is 490 trainning_loss: 0.044 trainning_accuracy: 0.984
# The trainning step is 500 trainning_loss: 0.019 trainning_accuracy: 1.000
# The trainning step is 510 trainning_loss: 0.038 trainning_accuracy: 1.000
# The trainning step is 520 trainning_loss: 0.022 trainning_accuracy: 1.000
# The trainning step is 530 trainning_loss: 0.024 trainning_accuracy: 1.000
# The trainning step is 540 trainning_loss: 0.025 trainning_accuracy: 1.000
# The trainning step is 550 trainning_loss: 0.021 trainning_accuracy: 1.000
# The trainning step is 560 trainning_loss: 0.039 trainning_accuracy: 0.984
# The trainning step is 570 trainning_loss: 0.019 trainning_accuracy: 1.000
# The trainning step is 580 trainning_loss: 0.019 trainning_accuracy: 1.000
# The trainning step is 590 trainning_loss: 0.014 trainning_accuracy: 1.000
# The trainning step is 600 trainning_loss: 0.017 trainning_accuracy: 1.000
# The trainning step is 610 trainning_loss: 0.027 trainning_accuracy: 0.992
# The trainning step is 620 trainning_loss: 0.015 trainning_accuracy: 1.000
# The trainning step is 630 trainning_loss: 0.009 trainning_accuracy: 1.000
# The trainning step is 640 trainning_loss: 0.013 trainning_accuracy: 1.000
# The trainning step is 650 trainning_loss: 0.019 trainning_accuracy: 0.992
# The trainning step is 660 trainning_loss: 0.020 trainning_accuracy: 0.992
# The trainning step is 670 trainning_loss: 0.017 trainning_accuracy: 0.992
# The trainning step is 680 trainning_loss: 0.021 trainning_accuracy: 0.992
# The trainning step is 690 trainning_loss: 0.009 trainning_accuracy: 1.000
# The trainning step is 700 trainning_loss: 0.012 trainning_accuracy: 1.000
# The trainning step is 710 trainning_loss: 0.010 trainning_accuracy: 1.000
# The trainning step is 720 trainning_loss: 0.014 trainning_accuracy: 1.000
# The trainning step is 730 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 740 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 750 trainning_loss: 0.008 trainning_accuracy: 1.000
# The trainning step is 760 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 770 trainning_loss: 0.008 trainning_accuracy: 1.000
# The trainning step is 780 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 790 trainning_loss: 0.006 trainning_accuracy: 1.000
# The trainning step is 800 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 810 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 820 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 830 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 840 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 850 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 860 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 870 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 880 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 890 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 900 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 910 trainning_loss: 0.008 trainning_accuracy: 1.000
# The trainning step is 920 trainning_loss: 0.006 trainning_accuracy: 1.000
# The trainning step is 930 trainning_loss: 0.006 trainning_accuracy: 1.000
# The trainning step is 940 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 950 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 960 trainning_loss: 0.006 trainning_accuracy: 1.000
# The trainning step is 970 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 980 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 990 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1000 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1010 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 1020 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1030 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1040 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 1050 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1060 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1070 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 1080 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1090 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1100 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1110 trainning_loss: 0.007 trainning_accuracy: 1.000
# The trainning step is 1120 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1130 trainning_loss: 0.006 trainning_accuracy: 1.000
# The trainning step is 1140 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1150 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1160 trainning_loss: 0.005 trainning_accuracy: 1.000
# The trainning step is 1170 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1180 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1190 trainning_loss: 0.006 trainning_accuracy: 1.000
# The trainning step is 1200 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1210 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 1220 trainning_loss: 0.009 trainning_accuracy: 1.000
# The trainning step is 1230 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1240 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1250 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1260 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1270 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1280 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1290 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1300 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1310 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1320 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1330 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1340 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1350 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1360 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1370 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1380 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1390 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1400 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1410 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1420 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1430 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1440 trainning_loss: 0.004 trainning_accuracy: 1.000
# The trainning step is 1450 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1460 trainning_loss: 0.003 trainning_accuracy: 1.000
# The trainning step is 1470 trainning_loss: 0.002 trainning_accuracy: 1.000
# The trainning step is 1480 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1490 trainning_loss: 0.001 trainning_accuracy: 1.000
# The trainning step is 1500 trainning_loss: 0.001 trainning_accuracy: 1.000

# %%
text_model.load_model(".\\models\\model-1500")
# Out:
# INFO:tensorflow:Restoring parameters from .\models\model-1500
# Restored from .\models\model-1500 completed

# %%
accuracy = text_model.predict_accuracy(devs,test=False)	
print('the dev accuracy is :',accuracy)
# Out:
# The trainning step is 1 trainning_accuracy: 0.789
# The trainning step is 2 trainning_accuracy: 0.734
# The trainning step is 3 trainning_accuracy: 0.766
# The trainning step is 4 trainning_accuracy: 0.719
# The trainning step is 5 trainning_accuracy: 0.727
# The trainning step is 6 trainning_accuracy: 0.750
# The trainning step is 7 trainning_accuracy: 0.719
# The trainning step is 8 trainning_accuracy: 0.703
# The trainning step is 9 trainning_accuracy: 0.619
# the dev accuracy is : 0.725033

# %%
predictions = text_model.predict(x_dev)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-71ce539535f6> in <module>()
# ----> 1 predictions = text_model.predict(x_dev)
#
# <ipython-input-3-ecf3caffe2c0> in predict(self, data)
#     219 					self.keep_prob:1.0}
#     220                         batch_pred = sess.run([self.predictions],feed_dict=feed)
# --> 221                         predictions_list.append(batch_pred)
#     222                 predictions = [list(pred) for pred in predictions]
#     223                 predictions = [p for pred in predictions for p in pred]
#
# NameError: name 'predictions_list' is not defined
